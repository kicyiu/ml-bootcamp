# %% [markdown]
# # Notebook Imports and Packages

# %%
import matplotlib.pyplot as plt
import numpy as np

from mpl_toolkits.mplot3d.axes3d import Axes3D
from matplotlib import cm #color map

from sympy import symbols, diff
from math import log

from sklearn.linear_model import LinearRegression

# %matplotlib inline

# %% [markdown]
# # Example 1 - A simple cost function
#
# ## $$f(x) = x^2 + x + 1$$

# %%
def f(x):
    return x**2 + x + 1

# %%
# Make Data

x_1 = np.linspace(start = -3, stop = 3, num = 100)

# %%
# Plot

plt.ylim(0, 8)
plt.xlim([-3, 3])
plt.xlabel('X', fontsize = 16)
plt.ylabel('f(x)', fontsize = 16)

plt.plot(x_1, f(x_1))
plt.show()

# %%
def df(x):
    return 2*x + 1

# %%
# Plot function and derivative side by side

plt.figure(figsize = [15, 5])

# 1 Chart: Cost Function
plt.subplot(1, 2, 1)

plt.xlim(-3, 3)
plt.ylim(0, 8)
plt.title('Cost Function', fontsize = 17)
plt.xlabel('X', fontsize = 16)
plt.ylabel('f(x)', fontsize = 16)
plt.plot(x_1, f(x_1), color = 'blue', linewidth = 3)

# 2 Chart: Derivative
plt.subplot(1, 2, 2)

plt.title('Slope of the cost function', fontsize = 17)
plt.xlabel('X', fontsize = 16)
plt.ylabel('df(x)', fontsize = 16)
plt.grid()
plt.xlim(-2, 3)
plt.ylim(-3, 6)

plt.plot(x_1, df(x_1), color = 'skyblue', linewidth = 5)

plt.show()

# %% [markdown]
# ## Python Loops & Gradient Descent

# %%
# Gradient Descent

new_x = 3 #starting point for make a Guess
previous_x = 0
step_multiplier = 0.1
precision = 0.0001

x_list = [new_x]
slope_list = [df(new_x)]

for n in range(500):
    previous_x = new_x
    gradient = df(previous_x)
    new_x = previous_x - step_multiplier * gradient
    
    step_size = abs(new_x - previous_x)
    
    x_list.append(new_x)
    slope_list.append(df(new_x))
    
    if step_size < precision:
        print('Loop run this many time:', n)
        break
    
print('Local minimum occurs at:', new_x)
print('Slope or df(x) value at this point is:', df(new_x))
print('f(x) value or cost at this point is:', f(new_x))
# Out:
# Loop run this many time: 40
# Local minimum occurs at: -0.49962781616118024
# Slope or df(x) value at this point is: 0.0007443676776395236
# f(x) value or cost at this point is: 0.7500001385208099

# %%
# Superimpose the gradient descent calculation on plot

plt.figure(figsize = [20, 5])

# 1 Chart: Cost Function
plt.subplot(1, 3, 1)

plt.xlim(-3, 3)
plt.ylim(0, 8)
plt.title('Cost Function', fontsize = 17)
plt.xlabel('X', fontsize = 16)
plt.ylabel('f(x)', fontsize = 16)
plt.plot(x_1, f(x_1), color = 'blue', linewidth = 3, alpha = 0.8)


values = np.array(x_list)
plt.scatter(x_list, f(values), color = 'red', s = 100, alpha = 0.6)

# 2 Chart: Derivative
plt.subplot(1, 3, 2)

plt.title('Slope of the cost function', fontsize = 17)
plt.xlabel('X', fontsize = 16)
plt.ylabel('df(x)', fontsize = 16)
plt.grid()
plt.xlim(-2, 3)
plt.ylim(-3, 6)

plt.plot(x_1, df(x_1), color = 'skyblue', linewidth = 5, alpha = 0.6)

plt.scatter(x_list, slope_list, color = 'red', s = 100, alpha = 0.5)

# 3 Chart: Derivative (Close Up)
plt.subplot(1, 3, 3)

plt.title('Gradient Descent (close up)', fontsize = 17)
plt.xlabel('X', fontsize = 16)
plt.grid()
plt.xlim(-0.55, -0.2)
plt.ylim(-0.3, 0.8)

plt.plot(x_1, df(x_1), color = 'skyblue', linewidth = 6, alpha = 0.8)
plt.scatter(x_list, slope_list, color = 'red', s = 300, alpha = 0.6)

plt.show()

# %% [markdown]
# # Example 2 - Multiple Minima vs Initial Guess & Advanced Functions
#
# ## $$g(x) = x^4 - 4x^2 + 5$$

# %%
# Make some data
x_2 = np.linspace(-2, 2, 1000)

# %%
def g(x):
    return x**4 - 4*x**2 + 5

def dg(x):
    return 4*x**3 - 8*x

# %%
# Plot function and derivative side by side

plt.figure(figsize = [15, 5])

# 1 Chart: Cost Function
plt.subplot(1, 2, 1)

plt.xlim(-2, 2)
plt.ylim(0.5, 5.5)
plt.title('Cost Function', fontsize = 17)
plt.xlabel('X', fontsize = 16)
plt.ylabel('g(x)', fontsize = 16)
plt.plot(x_2, g(x_2), color = 'blue', linewidth = 3)

# 2 Chart: Derivative
plt.subplot(1, 2, 2)

plt.title('Slope of the cost function', fontsize = 17)
plt.xlabel('X', fontsize = 16)
plt.ylabel('dg(x)', fontsize = 16)
plt.grid()
plt.xlim(-2, 2)
plt.ylim(-6, 8)

plt.plot(x_2, dg(x_2), color = 'skyblue', linewidth = 5)

plt.show()

# %% [markdown]
# ## Gradient Descent as a Python Function

# %%
def gradient_descent(derivative_function, initial_guess, multiplier=0.02, precision=0.001,
                    max_iter=300):

    new_x = initial_guess #starting point for make a Guess
    #previous_x = 0
    #step_multiplier = 0.1
    #precision = 0.0001

    x_list = [new_x]
    slope_list = [derivative_function(new_x)]

    for n in range(max_iter):
        previous_x = new_x
        gradient = derivative_function(previous_x)
        new_x = previous_x - multiplier * gradient

        step_size = abs(new_x - previous_x)

        x_list.append(new_x)
        slope_list.append(derivative_function(new_x))

        if step_size < precision:
            break
    
    return new_x, x_list, slope_list

# %%
local_min, list_x, deriv_list = gradient_descent(dg, 0.5, 0.02, 0.001)
print('Local min occur at: ', local_min)
print('Number os steps: ', len(list_x))
# Out:
# Local min occur at:  1.4122375085019094
# Number os steps:  23

# %%
local_min, list_x, deriv_list = gradient_descent(derivative_function=dg, initial_guess=-0.5,
                                                 multiplier=0.01, precision=0.0001)
print('Local min occur at: ', local_min)
print('Number os steps: ', len(list_x))
# Out:
# Local min occur at:  -1.4137636556157256
# Number os steps:  56

# %%
local_min, list_x, deriv_list = gradient_descent(derivative_function=dg, initial_guess=-0.1)
print('Local min occur at: ', local_min)
print('Number os steps: ', len(list_x))
# Out:
# Local min occur at:  -1.4120887490901561
# Number os steps:  34

# %%
# Calling gradient descent function
local_min, list_x, deriv_list = gradient_descent(derivative_function=dg, initial_guess=0.1)
print('Local min occur at: ', local_min)
print('Number os steps: ', len(list_x))

# Plot function and derivative and scatter plot side by side

plt.figure(figsize = [15, 5])

# 1 Chart: Cost Function
plt.subplot(1, 2, 1)

plt.xlim(-2, 2)
plt.ylim(0.5, 5.5)
plt.title('Cost Function', fontsize = 17)
plt.xlabel('X', fontsize = 16)
plt.ylabel('g(x)', fontsize = 16)

plt.plot(x_2, g(x_2), color = 'blue', linewidth = 3, alpha=0.8)
plt.scatter(list_x, g(np.array(list_x)), color='red', s=100, alpha=0.6)

# 2 Chart: Derivative
plt.subplot(1, 2, 2)

plt.title('Slope of the cost function', fontsize = 17)
plt.xlabel('X', fontsize = 16)
plt.ylabel('dg(x)', fontsize = 16)
plt.grid()
plt.xlim(-2, 2)
plt.ylim(-6, 8)

plt.plot(x_2, dg(x_2), color = 'skyblue', linewidth=5, alpha=0.6)
plt.scatter(list_x, deriv_list, color='red', s=100, alpha=0.5)

plt.show()
# Out:
# Local min occur at:  1.4139365672604374
# Number os steps:  16

# %% [markdown]
# # Example 3 Divergence, Overflow and Python Tuples
#
# ## $$h(x) = x^5 -2x^4 + 2$$

# %%
# Make data
x_3 = np.linspace(start=-2.5, stop=2.5, num=1000)

def h(x):
    return x**5 - 2*x**4 + 2

def dh(x):
    return 5*x**4 - 8*x**3

# %%
# Calling gradient descent function
local_min, list_x, deriv_list = gradient_descent(derivative_function=dh, initial_guess=-0.2,
                                                max_iter=70)


# Plot function and derivative and scatter plot side by side

plt.figure(figsize = [15, 5])

# 1 Chart: Cost Function
plt.subplot(1, 2, 1)

plt.xlim(-1.2, 2.5)
plt.ylim(-1, 4)
plt.title('Cost Function', fontsize = 17)
plt.xlabel('X', fontsize = 16)
plt.ylabel('h(x)', fontsize = 16)

plt.plot(x_3, h(x_3), color = 'blue', linewidth = 3, alpha=0.8)
plt.scatter(list_x, h(np.array(list_x)), color='red', s=100, alpha=0.6)

# 2 Chart: Derivative
plt.subplot(1, 2, 2)

plt.title('Slope of the cost function', fontsize = 17)
plt.xlabel('X', fontsize = 16)
plt.ylabel('dh(x)', fontsize = 16)
plt.grid()
plt.xlim(-1, 2)
plt.ylim(-4, 5)

plt.plot(x_3, dh(x_3), color = 'skyblue', linewidth=5, alpha=0.6)
plt.scatter(list_x, deriv_list, color='red', s=100, alpha=0.5)

plt.show()

print('Local min occur at: ', local_min)
print('Cost at this minimum is: ', h(local_min))
print('Number os steps: ', len(list_x))
# Out:
# Local min occur at:  -2071072.4470816324
# Cost at this minimum is:  -3.810455326061589e+31
# Number os steps:  71

# %%
import sys
# help(sys)
# sys.version
# type(h(local_min))
sys.float_info.max
# Out:
# 1.7976931348623157e+308

# %% [markdown]
# # Python Tuples

# %%
# Creating a tuple
breakfast = 'bacon', 'eggs', 'avocado'
unlucky_numbers = 13, 4, 9, 26, 17

# How to access a value in a tuple
print('I looooove breakfast', breakfast[0])
print('My hotel has no ' + str(unlucky_numbers[1]) + 'th floor')

# Unpacking tuples
main, side, greens = breakfast
print('Main course is ', main)

# Unpacking tuples or function valaues by index
data_tuple = gradient_descent(derivative_function=dh, initial_guess=0.2)
print('Locan min is', data_tuple[0])
print('Cost at the last x value is', h(data_tuple[0]))
print('Number of step is', len(data_tuple[1]))
# Out:
# I looooove breakfast bacon
# My hotel has no 4th floor
# Main course is  bacon
# Locan min is 1.5989534547394717
# Cost at the last x value is -0.6214287992331258
# Number of step is 117

# %% [markdown]
# # The Learning Rate

# %%
# Calling gradient descent function
local_min, list_x, deriv_list = gradient_descent(derivative_function=dg, initial_guess=1.9,
                                                multiplier=0.02, max_iter=500)

# Plot function and derivative and scatter plot side by side

plt.figure(figsize = [15, 5])

# 1 Chart: Cost Function
plt.subplot(1, 2, 1)

plt.xlim(-2, 2)
plt.ylim(0.5, 5.5)
plt.title('Cost Function', fontsize = 17)
plt.xlabel('X', fontsize = 16)
plt.ylabel('g(x)', fontsize = 16)

plt.plot(x_2, g(x_2), color = 'blue', linewidth = 3, alpha=0.8)
plt.scatter(list_x, g(np.array(list_x)), color='red', s=100, alpha=0.6)

# 2 Chart: Derivative
plt.subplot(1, 2, 2)

plt.title('Slope of the cost function', fontsize = 17)
plt.xlabel('X', fontsize = 16)
plt.ylabel('dg(x)', fontsize = 16)
plt.grid()
plt.xlim(-2, 2)
plt.ylim(-6, 8)

plt.plot(x_2, dg(x_2), color = 'skyblue', linewidth=5, alpha=0.6)
plt.scatter(list_x, deriv_list, color='red', s=100, alpha=0.5)

plt.show()

print('Number of steps is: ', len(list_x))
# Out:
# Number of steps is:  14

# %%
# Run gradient descent 3 time
n = 100
low_gamma = gradient_descent(derivative_function=dg, initial_guess=3,
                                                multiplier=0.0005, precision=0.0001, max_iter=n)

mid_gamma = gradient_descent(derivative_function=dg, initial_guess=3,
                                                multiplier=0.001, precision=0.0001, max_iter=n)

high_gamma = gradient_descent(derivative_function=dg, initial_guess=3,
                                                multiplier=0.002, precision=0.0001, max_iter=n)

# Experiment
insane_gamma = gradient_descent(derivative_function=dg, initial_guess=1.9,
                                                multiplier=0.25, precision=0.0001, max_iter=n)

# Plotting reduction in cost for each iteration
plt.figure(figsize = [20, 10])

plt.xlim(0, n)
plt.ylim(0, 50)
plt.title('Effect of the learninf rate', fontsize = 17)
plt.xlabel('Nr of iterations', fontsize = 16)
plt.ylabel('Cost', fontsize = 16)

# Value for our charts
# 1) Y Axis Data: convert the lists to numpy arrays
low_values = np.array(low_gamma[1])

# 2) X Axis Data: create a list from 0 to n + 1
iteration_list = list(range(0, n + 1))

# Plotting low learning rate
plt.plot(iteration_list, g(low_values), color = 'lightgreen', linewidth = 5)
plt.scatter(iteration_list, g(low_values), color='lightgreen', s=80)

# Plotting mid learning rate
plt.plot(iteration_list, g(np.array(mid_gamma[1])), color = 'steelblue', linewidth = 5)
plt.scatter(iteration_list, g(np.array(mid_gamma[1])), color='steelblue', s=80)

# Plotting high learning rate
plt.plot(iteration_list, g(np.array(high_gamma[1])), color = 'hotpink', linewidth = 5)
plt.scatter(iteration_list, g(np.array(high_gamma[1])), color='hotpink', s=80)

# Plotting insane learning rate
plt.plot(iteration_list, g(np.array(insane_gamma[1])), color = 'red', linewidth = 5)
plt.scatter(iteration_list, g(np.array(insane_gamma[1])), color='red', s=80)

plt.show()

# %% [markdown]
# The Graphic shows that the higher is the learning rate the fastest we will reach the minimum

# %% [markdown]
# # Example 4 - Data Viz with 3D Charts
#
# ## Minimise $$f(x, y) = \frac{1}{3^{-x^2 - y^2} +1}$$
#
# Minimise $$f(x, y) = \frac{1}{r + 1}$$ where $r$ is $3^{-x^2 - y^2}$

# %%
def f(x, y):
    r = 3**(-x**2 - y**2)
    return 1 / (r + 1)

# %%
# Make our x and y data
x_4 = np.linspace(start=-2, stop=2, num=200)
y_4 = np.linspace(start=-2, stop=2, num=200)

print('Shape of X array', x_4.shape)

x_4, y_4 = np.meshgrid(x_4, y_4)
print('After array meshgrid', x_4.shape)
# Out:
# Shape of X array (200,)
# After array meshgrid (200, 200)
# After array meshgrid (200, 200)

# %%
# Generating 3D Plot
fig = plt.figure(figsize = [16, 12])
ax = fig.gca(projection='3d')  #gca is short of get current axis

ax.set_xlabel('X', fontsize=20)
ax.set_ylabel('Y', fontsize=20)
ax.set_zlabel('f(x, y) - Cost', fontsize=20)

ax.plot_surface(x_4, y_4, f(x_4, y_4), cmap=cm.winter, alpha=0.4)

plt.show()

# %% [markdown]
# ## Partial Derivatives & Symbolic Computation
# ## $$\frac{\partial f}{\partial x} = \frac{2x \ln(3) \cdot 3^{-x^2 -y^2}}{\left(3^{-x^2 - y^2} + 1\right)^2} $$
# ## $$\frac{\partial f}{\partial y} = \frac{2y \ln(3) \cdot 3^{-x^2 -y^2}}{\left(3^{-x^2 - y^2} + 1\right)^2} $$

# %%
a, b = symbols('x, y')
print('Our cost function(x, y) is: ', f(a, b))
print('Partial derivative with respect to x is: ', diff(f(a, b), a))
print('Value of f(x, y) at x=1.8 y=10. is: ', f(a, b).evalf(subs={a:1.8, b:1.0})) #Phyton Dictionary

print('Value of partial derivartive with respect to x : ', diff(f(a, b), a).evalf(subs={a:1.8, b:1.0}))
# Out:
# Our cost function(x, y) is:  1/(3**(-x**2 - y**2) + 1)
# Partial derivative with respect to x is:  2*3**(-x**2 - y**2)*x*log(3)/(3**(-x**2 - y**2) + 1)**2
# Value of f(x, y) at x=1.8 y=10. is:  0.990604794032582
# Value of partial derivartive with respect to x :  0.0368089716197505

# %% [markdown]
# ## Bath Gradient Descent with Sympy

# %%
# Setup
multiplier = 0.1
max_iter = 500
params = np.array([1.8, 1.0]) # Initial guess

for n in range(max_iter):
    # In these three lines of code we are calculating our cost and how far away
    # we are from the minimum base on the deepnest of the slope. This is the learning step
    gradient_x = diff(f(a, b), a).evalf(subs={a: params[0], b: params[1]})
    gradient_y = diff(f(a, b), b).evalf(subs={a: params[0], b: params[1]})
    gradients = np.array([gradient_x, gradient_y])
    params = params - multiplier * gradients

print('Values in gradient array: ', gradients)
print('Minimun occurs at a x value of: ', params[0])
print('Minimun occurs at a y value of: ', params[1])
print('The cost is: ', f(params[0], params[1]))
# Out:
# Values in gradient array:  [2.01013037525579e-11 1.11673909736433e-11]
# Minimun occurs at a x value of:  3.45838599885832e-11
# Minimun occurs at a y value of:  1.92132555492129e-11
# The cost is:  0.500000000000000

# %%
# Partial derivative functions example 4

def fpx(x, y):
    r = 3**(-x**2 -y**2)
    return (2 * x * log(3) * r) / (r + 1)**2

def fpy(x, y):
    r = 3**(-x**2 -y**2)
    return (2 * y * log(3) * r) / (r + 1)**2

# %%
# Setup
multiplier = 0.1
max_iter = 500
params = np.array([1.8, 1.0]) # Initial guess

for n in range(max_iter):
    # In these three lines of code we are calculating our cost and how far away
    # we are from the minimum base on the deepnest of the slope. This is the learning step
    gradient_x = fpx(params[0], params[1])
    gradient_y = fpy(params[0], params[1])
    gradients = np.array([gradient_x, gradient_y])
    params = params - multiplier * gradients

print('Values in gradient array: ', gradients)
print('Minimun occurs at a x value of: ', params[0])
print('Minimun occurs at a y value of: ', params[1])
print('The cost is: ', f(params[0], params[1]))
# Out:
# Values in gradient array:  [2.01013038e-11 1.11673910e-11]
# Minimun occurs at a x value of:  3.458385998858304e-11
# Minimun occurs at a y value of:  1.9213255549212797e-11
# The cost is:  0.5

# %% [markdown]
# ## Graphing 3D Gradient Descent & Adv Numpy Arrays

# %%
# Setup
multiplier = 0.1
max_iter = 200
params = np.array([1.8, 1.0]) # Initial guess
values_array = params.reshape(1, 2)
print(values_array.shape)

for n in range(max_iter):
    # In these three lines of code we are calculating our cost and how far away
    # we are from the minimum base on the deepnest of the slope. This is the learning step
    gradient_x = fpx(params[0], params[1])
    gradient_y = fpy(params[0], params[1])
    gradients = np.array([gradient_x, gradient_y])
    params = params - multiplier * gradients
    # values_array = np.append(values_array, params.reshape(1, 2), axis=0)
    values_array = np.concatenate((values_array, params.reshape(1, 2)), axis=0) # another way of concatenation

print('Values in gradient array: ', gradients)
print('Minimun occurs at a x value of: ', params[0])
print('Minimun occurs at a y value of: ', params[1])
print('The cost is: ', f(params[0], params[1]))
# Out:
# (1, 2)
# Values in gradient array:  [0.00046144 0.00025636]
# Minimun occurs at a x value of:  0.0007938985101347202
# Minimun occurs at a y value of:  0.0004410547278526219
# The cost is:  0.5000002265349848

# %%
# Generating 3D Plot
fig = plt.figure(figsize = [16, 12])
ax = fig.gca(projection='3d')  #gca is short of get current axis

ax.set_xlabel('X', fontsize=20)
ax.set_ylabel('Y', fontsize=20)
ax.set_zlabel('f(x, y) - Cost', fontsize=20)

ax.plot_surface(x_4, y_4, f(x_4, y_4), cmap=cm.coolwarm, alpha=0.4)
ax.scatter(values_array[:, 0], values_array[:, 1], 
           f(values_array[:, 0], values_array[:, 1]), s=50, color='red')

plt.show()

# %%
# Advanced Numpy Array Practice:

kirk = np.array([['Captain', 'Guitar']])
print(kirk.shape)

hs_band = np.array([['Black Thought', 'MC'], ['Questloves', 'Drums']])
print(hs_band.shape)

print('hs_band[0]    : ', hs_band[0])
print('hs_band[1][0]    : ', hs_band[1][0])

the_roots = np.append(arr=hs_band, values=kirk, axis=0) # concat a new row, axis 0 means in row direction, axis=1 for columns direction
print(the_roots)

print('Printing nick names: ', the_roots[:, 0])

the_roots = np.append(arr=the_roots, values=[['Malik B', 'MC']], axis=0)
print('Printing band roles: ', the_roots[:, 1])
# Out:
# (1, 2)
# (2, 2)
# hs_band[0]    :  ['Black Thought' 'MC']
# hs_band[1][0]    :  Questloves
# [['Black Thought' 'MC']
#  ['Questloves' 'Drums']
#  ['Captain' 'Guitar']]
# Printing nick names:  ['Black Thought' 'Questloves' 'Captain']
# Printing band roles:  ['MC' 'Drums' 'Guitar' 'MC']

# %% [markdown]
# # Example 5 - Working with Data & a Real Cost Function
#
# ## Mean Squared Error: a cost function for regression problems
#
# ### $$RSS = \sum_{i=1}^{n} \big( y^{(i)} - h_\theta x^{(i)} \big)^2 $$
# ### $$MSE = \frac{1}{n} \sum_{i=1}^{n} \big( y^{(i)} - h_\theta x^{(i)} \big)^2 $$
# ### $$MSE = \frac{1}{n} \sum_{i=1}^{n} \big( y - \hat{y} \big)^2 $$

# %%
# Make sample data
x_5 = np.array([[0.1, 1.2, 2.4, 3.2, 4.1, 5.7, 6.5]]).transpose() # reshape the 2D array
y_5 = np.array([1.7, 2.4, 3.5, 3.0, 6.1, 9.4, 8.2]).reshape(7, 1) # another way to reshape

print('shape of x_5 array: ', x_5.shape)
print('shape of y_5 array: ', y_5.shape)
# Out:
# shape of x_5 array:  (7, 1)
# shape of y_5 array:  (7, 1)

# %%
# Quick linear regression
regr = LinearRegression()
regr.fit(x_5, y_5)
print('Theta 0:', regr.intercept_[0])
print('Theta 1:', regr.coef_[0][0])
# Out:
# Theta 0: 0.8475351486029536
# Theta 1: 1.2227264637835915

# %%
plt.scatter(x_5, y_5, s= 50)
plt.plot(x_5, regr.predict(x_5), color='orange', lineWidth=3)
plt.xlabel('x values')
plt.xlabel('y values')
plt.show()

# %%
print(regr.predict(x_5))
# Out:
# [[0.96980779]
#  [2.31480691]
#  [3.78207866]
#  [4.76025983]
#  [5.86071365]
#  [7.81707599]
#  [8.79525716]]
